# %% [markdown]
# # Introduction to Figma Grids
#
# ---

# %% [markdown]
# ## Abstract

# %% [markdown]
# **Tired of “eye-balling” and “wild guessing” through spacing and alignment?**
#
# Grids are just the right tool for your designs. It leverages a good design to a great design. Alignment being a simple yet powerful part of any UI design; is key in balancing various elements and maintaining a visual hierarchy. It helps build a consistent structure throughout the interface and creates a visual connection with the user.

# %% [markdown]
# Figma Grids are a great way of arranging UI elements. Some of the key points about figma grids are:
#
# >*   It helps you craft consistent and responsive designs.
# *   They are easy to implement and helps improve readability from page to page.
# *   The grid system works on a series of columns and rows.
# *   Creating re-usable components speeds up the workflow
# *   It improves the efficiency of the design process.
# *   It helps equally spacing and positioning elements.
#
#
#  In simple terms, it acts as a backbone to layout designs.

# %% [markdown]
# ## Layout Grids
#
# Some basic terminologies to get started with layout grids are:
# >* Columns: The vertical spatial zones of the screen where content is arranged.
# * Rows: The horizontal spatial zones  of the screen that extends from left to right.
# * Gutters: The spaces between columns and rows that separates columns and rows.
# * Margins: The spacing that separates content and in the far left and right sections of the screen.

# %% [markdown]
# ## Understanding Grids
# >*	Layout grid is compatible for **frames** of any screen resolution. A grid can also be set on any component with frames included. Grids simplify responsive web design i.e. it works great on desktop, tablet and mobile frames and helps easy switching between them.
# *	**Nested grids** are a powerful feature of figma grids. In simple words, it gives you the functionality to add multiple grids to the same frame for differnet parts of your design. Switching between grids can be done by toggling the visibility. Grids can be differentiated by specifying your choice of **shades and opacities**.
# *	Modifications in the grid parameters are simplified and you can easily use the same grid pattern across multiple frames by simply group selecting the grids and pasting it onto your desired frame.

# %% [markdown]
# Layout Grids are of three kinds:
# >1. Uniform Grids
# 2. Column Grids
# 3. Baseline Grids
#
# Figma grids gives you a great flexibility to improvise upon your designs.

# %% [markdown]
# ## Create your own Layout Grid

# %% [markdown]
# >1. To get started, select a frame to apply the layout grid.
# 2. Click on the ‘+’ icon beside the Layout Grid in the properties panel to create a grid.

# %% [markdown]
# ![Group 1 (2).png](data:image/png;base64,...)

# %% [markdown]
# >3. Parameters like size, color and opacity are flexible to be updated according to your designs.

# %% [markdown]
# **Uniform grids** provides a uniformly spaced set of rows and columns that can help you easily organize and align design elements.
#
# >>![grid1.png](data:image/png;base64,...)

# %% [markdown]
# **Column grids** have a great similarity with the HTML grids and provide great functionality to design responsive web components.A 12 column schema is mostly used to align design elements.
#
# >>![grid2.png](data:image/png;base64,...)

# %% [markdown]
# **Rows or Baseline grids** are a great way to align text elements. Setting offset values to your text blocks using auto layout can help you keep a consistent flow of design regardless of the font style.
#
# >>![grid3.png](data:image/png;base64,...)

# %% [markdown]
# ####Type
# Type parameter of column are Stretch, Left and Center, while row are Stretch, Top, Bottom and Center.
#
# >* Stretch: It automatically grow or shink the width of the column/row when you resize the frame.
# * Center: It follows a centered gridline. It comes in handy for ultra wide screen displays where much of the horizontal spacing may not be utilized.
# * Left: It shifts the layout grid to the leftmost edge of the frame.
# * Top: It sets the row guides to the top of the design frame.
# * Bottom: It sets the row guides to the bottom of the design frame.

# %% [markdown]
# ####Offset
#
# It is used to adjust space at the begining of the grid(i.e. top or left).

# %% [markdown]
# ####Count
# The number of columns/rows can be chosen based on the precision of the design.

# %% [markdown]
# ##Nudge Amount
#
# Setting the right nudge amount according to the grid is required to enable proper aligning.
#
# * Click on the menu.
# * Go to Preferences
# * Then click on Nudge amount
# * Enter your desired Small nudge and Big nudge details.
#
# Big nudge: Adjusting the big nudge varies the amount of gridlines will shift upon using shift+direction keys. For example, in 8pt grids the approriate big nudge amount is 8.
#
# Small nudge: Adjusting the small nudge varies the amount of gridlines the elements will shift while using the direction keys alone.

# %% [markdown]
# ##Nested Grids
#
# Nested grids are a great way of perfecting design measurements. Toggle between the visibilities of different grids to specifically modify grids.
#
# ![nest.png](data:image/png;base64,...)

# %% [markdown]
# ##Additional Tips
#
# * The visiblity of the grids can be individually toggled using the eye button corresponding to the grid or the shortcut Ctrl+G.
# * Understanding different grid systems like 8pt grids can fasten up the deisgn process and bring uniformity.
# * While using a layout grid, adjusting the nudge amount is key.
# * You can select a single layout grid and apply this to multiple frames by simply copy pasting them. This way, you can create a layout grid style that can be reused across your designs.

# %% [markdown]
# To conclude figma grids are a real game changer. Functionalities that grids provide can transform the design process and organize your workflow.
#
# Happy Designing!
