# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavindra-Mohan-Dwivedi/winter-of-contributing/blob/DSA/Tree_Traversal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tree Traversal
# Printing Each and every element of a tree is call tree traversing.
# It can be performed my following ways
#
#                                     Tree Traversal
#                                            |
#                    |----------------------------------------------|
#            Depth First Traversal                         Bredth First Traversal
#                    |
#        |-----------|------------|
#     Preorder    Inorder   PostOrder
# ---

# %% [markdown]
# ## Depth First Traversal
# In DFS we go to one side of the node and traverse it completely and then wo go to another side of the node and traverse it.
#
# ![Bredth First Traversal.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Preorder Traversal
# In Preorder Traversal first the node element is printed then the left subtree of the node element and then the elements of right subtree
#
# ![Tree-Traversals-Preorder.png](data:image/png;base64,...)
#
# Output : 1 2 4 5 3 6 7

# %% [markdown]
# ```
#  void printPreorder(Node node)
#     {
#         if (node == null)
#             return;
#
#         /* first print data of node */
#         System.out.print(node.key + " ");
#
#         /* then recur on left sutree */
#         printPreorder(node.left);
#
#         /* now recur on right subtree */
#         printPreorder(node.right);
#     }
# ```

# %% [markdown]
# ### Inorder Traversal
# In Inorder traversal first the elements left side of the node are printed then the node element itself and at last elements of right side of nodes are printed.
#
# ![Tree-Traversals-Preorder.png](data:image/png;base64,...)
#
# Output : 4 2 5 1 6 3 7

# %% [markdown]
# ```
#  void Inorder(Node node)
#     {
#         if (node == null)
#             return;
#
#         /* first recur on left child */
#         printInorder(node.left);
#
#         /* then print the data of node */
#         System.out.print(node.key + " ");
#
#         /* now recur on right child */
#         printInorder(node.right);
#     }
# ```

# %% [markdown]
# ### Postorder Traversal
# In Postorder traversal first the right subtree is printed then the left subtree and at last the node element.
#
#
# ![Tree-Traversals-Preorder.png](data:image/png;base64,...)
#
# Output : 7 6 3 5 4 2 1

# %% [markdown]
# ```
# void printPostorder(Node node)
#     {
#         if (node == null)
#             return;
#
#         // first recur on left subtree
#         printPostorder(node.left);
#
#         // then recur on right subtree
#         printPostorder(node.right);
#
#         // now deal with the node
#         System.out.print(node.key + " ");
#     }
# ```

# %% [markdown]
# # Breadth First Traversal
# In Breadth first traversal the elements are printed level by leve i.e first the node element will be printed then the next level until there is no level left.
#
# ![Tree-Traversals-Preorder.png](data:image/png;base64,...)
#
# Output : 1 2 3 4 5 6 7

# %% [markdown]
# void printLevelOrder()
#     {
#         Queue<Node> queue = new LinkedList<Node>();
#         queue.add(root);
#         while (!queue.isEmpty())
#         {
#
#
#             Node tempNode = queue.poll();
#             System.out.print(tempNode.data + " ");
#
#
#             if (tempNode.left != null) {
#                 queue.add(tempNode.left);
#             }
#
#
#             if (tempNode.right != null) {
#                 queue.add(tempNode.right);
#             }
#         }
#     }
