# %% [markdown]
# # Long Short Term Memory [LSTM]

# %% [markdown]
# ### Importing the necessary libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %% [markdown]
# ## Importing Dataset

# %%
data = pd.read_csv('https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv')

# %%
data.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
data.tail()
# Out:
#             Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2030  2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
# 2031  2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2032  2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2033  2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2034  2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
#
#       Turnover (Lacs)
# 2030           694.98
# 2031           780.01
# 2032           340.31
# 2033           355.17
# 2034           803.56

# %% [markdown]
# ## Data Preprocessing and Visulaisation

# %%
data['Date'] = pd.to_datetime(data['Date'])
df = data.sort_values(by='Date')
df.head()
# Out:
#            Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2034 2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
# 2033 2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2032 2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2031 2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2030 2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
#
#       Turnover (Lacs)
# 2034           803.56
# 2033           355.17
# 2032           340.31
# 2031           780.01
# 2030           694.98

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index       Date   Open    High     Low    Last   Close  \
# 0   2034 2010-07-21  122.1  123.00  121.05  121.10  121.55
# 1   2033 2010-07-22  120.3  122.00  120.25  120.75  120.90
# 2   2032 2010-07-23  121.8  121.95  120.25  120.35  120.65
# 3   2031 2010-07-26  120.1  121.00  117.10  117.10  117.60
# 4   2030 2010-07-27  117.6  119.50  112.00  118.80  118.65
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                658666           803.56
# 1                293312           355.17
# 2                281312           340.31
# 3                658440           780.01
# 4                586100           694.98

# %%
plt.plot(df['Close'])

# %%
df1 = df['Close']

# %%
scaler = MinMaxScaler(feature_range=(0,1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))
df1
# Out:
# array([[0.16584967],
#        [0.16319444],
#        [0.1621732 ],
#        ...,
#        [0.62622549],
#        [0.62214052],
#        [0.62418301]])

# %% [markdown]
# ## Training and Testing Dataset

# %%
training_size = int(len(df1)*0.70)
test_size = len(df1) - training_size


train_data = df1[0:training_size,:]
test_data = df1[training_size:len(df1), :1]

# %%
training_size, test_size
# Out:
# (1424, 611)

# %%
def datasetCrtd(dataset, time_step=1):
  dataX, dataY = [], []
  for i in range(len(dataset)-time_step-1):
    a = dataset[i:(i+time_step), 0]
    dataX.append(a)
    dataY.append(dataset[i + time_step, 0])

  return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = datasetCrtd(train_data, time_step)
X_test, ytest = datasetCrtd(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (1323, 100)
# (1323,)
# (None, None)

# %% [markdown]
# ## Model Building

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100,1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, validation_split=0.1, epochs=60, batch_size=64, verbose=1)
# Out:
# Epoch 1/60
# 19/19 [==============================] - 7s 229ms/step - loss: 0.0112 - val_loss: 0.0013
# Epoch 2/60
# 19/19 [==============================] - 3s 184ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 3/60
# 19/19 [==============================] - 3s 186ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 4/60
# 19/19 [==============================] - 4s 190ms/step - loss: 9.5663e-04 - val_loss: 0.0012
# Epoch 5/60
# 19/19 [==============================] - 3s 136ms/step - loss: 8.3784e-04 - val_loss: 0.0011
# Epoch 6/60
# 19/19 [==============================] - 3s 167ms/step - loss: 8.1935e-04 - val_loss: 0.0011
# Epoch 7/60
# 19/19 [==============================] - 4s 213ms/step - loss: 8.0450e-04 - val_loss: 0.0011
# Epoch 8/60
# 19/19 [==============================] - 3s 150ms/step - loss: 7.6110e-04 - val_loss: 9.9232e-04
# Epoch 9/60
# 19/19 [==============================] - 3s 164ms/step - loss: 7.7604e-04 - val_loss: 9.4461e-04
# Epoch 10/60
# 19/19 [==============================] - 3s 164ms/step - loss: 7.3487e-04 - val_loss: 8.9341e-04
# Epoch 11/60
# 19/19 [==============================] - 3s 147ms/step - loss: 7.1761e-04 - val_loss: 8.6269e-04
# Epoch 12/60
# 19/19 [==============================] - 3s 147ms/step - loss: 6.7597e-04 - val_loss: 8.2726e-04
# Epoch 13/60
# 19/19 [==============================] - 3s 133ms/step - loss: 6.9496e-04 - val_loss: 7.9634e-04
# Epoch 14/60
# 19/19 [==============================] - 3s 157ms/step - loss: 6.4848e-04 - val_loss: 7.6739e-04
# Epoch 15/60
# 19/19 [==============================] - 2s 127ms/step - loss: 6.4330e-04 - val_loss: 7.3729e-04
# Epoch 16/60
# 19/19 [==============================] - 3s 140ms/step - loss: 6.4163e-04 - val_loss: 7.1910e-04
# Epoch 17/60
# 19/19 [==============================] - 3s 139ms/step - loss: 6.1609e-04 - val_loss: 6.9410e-04
# Epoch 18/60
# 19/19 [==============================] - 3s 141ms/step - loss: 6.3949e-04 - val_loss: 6.7411e-04
# Epoch 19/60
# 19/19 [==============================] - 3s 134ms/step - loss: 6.3505e-04 - val_loss: 6.5402e-04
# Epoch 20/60
# 19/19 [==============================] - 3s 132ms/step - loss: 5.5969e-04 - val_loss: 6.3938e-04
# Epoch 21/60
# 19/19 [==============================] - 2s 129ms/step - loss: 5.4024e-04 - val_loss: 6.8707e-04
# Epoch 22/60
# 19/19 [==============================] - 2s 128ms/step - loss: 5.2731e-04 - val_loss: 6.0971e-04
# Epoch 23/60
# 19/19 [==============================] - 3s 136ms/step - loss: 5.1485e-04 - val_loss: 5.8474e-04
# Epoch 24/60
# 19/19 [==============================] - 3s 148ms/step - loss: 5.0572e-04 - val_loss: 6.2290e-04
# Epoch 25/60
# 19/19 [==============================] - 3s 129ms/step - loss: 4.9262e-04 - val_loss: 5.5395e-04
# Epoch 26/60
# 19/19 [==============================] - 3s 140ms/step - loss: 4.8444e-04 - val_loss: 4.9932e-04
# Epoch 27/60
# 19/19 [==============================] - 2s 125ms/step - loss: 4.8318e-04 - val_loss: 5.2559e-04
# Epoch 28/60
# 19/19 [==============================] - 3s 143ms/step - loss: 4.5100e-04 - val_loss: 4.6548e-04
# Epoch 29/60
# 19/19 [==============================] - 3s 134ms/step - loss: 4.3210e-04 - val_loss: 4.3902e-04
# Epoch 30/60
# 19/19 [==============================] - 3s 144ms/step - loss: 4.4087e-04 - val_loss: 4.7707e-04
# Epoch 31/60
# 19/19 [==============================] - 3s 135ms/step - loss: 4.0995e-04 - val_loss: 4.2334e-04
# Epoch 32/60
# 19/19 [==============================] - 3s 144ms/step - loss: 3.9478e-04 - val_loss: 4.2532e-04
# Epoch 33/60
# 19/19 [==============================] - 3s 132ms/step - loss: 3.9659e-04 - val_loss: 3.7059e-04
# Epoch 34/60
# 19/19 [==============================] - 3s 136ms/step - loss: 3.6878e-04 - val_loss: 3.4536e-04
# Epoch 35/60
# 19/19 [==============================] - 3s 131ms/step - loss: 3.5603e-04 - val_loss: 4.1632e-04
# Epoch 36/60
# 19/19 [==============================] - 3s 142ms/step - loss: 3.4246e-04 - val_loss: 3.2089e-04
# Epoch 37/60
# 19/19 [==============================] - 2s 126ms/step - loss: 3.2303e-04 - val_loss: 3.0829e-04
# Epoch 38/60
# 19/19 [==============================] - 3s 138ms/step - loss: 3.1749e-04 - val_loss: 3.1931e-04
# Epoch 39/60
# 19/19 [==============================] - 3s 140ms/step - loss: 2.9856e-04 - val_loss: 2.7890e-04
# Epoch 40/60
# 19/19 [==============================] - 3s 131ms/step - loss: 2.8193e-04 - val_loss: 2.6082e-04
# Epoch 41/60
# 19/19 [==============================] - 3s 131ms/step - loss: 2.8311e-04 - val_loss: 3.0950e-04
# Epoch 42/60
# 19/19 [==============================] - 3s 132ms/step - loss: 2.7557e-04 - val_loss: 2.6302e-04
# Epoch 43/60
# 19/19 [==============================] - 3s 149ms/step - loss: 2.6031e-04 - val_loss: 3.2847e-04
# Epoch 44/60
# 19/19 [==============================] - 3s 132ms/step - loss: 2.7185e-04 - val_loss: 2.3321e-04
# Epoch 45/60
# 19/19 [==============================] - 3s 142ms/step - loss: 2.5201e-04 - val_loss: 2.1614e-04
# Epoch 46/60
# 19/19 [==============================] - 3s 131ms/step - loss: 2.8502e-04 - val_loss: 2.0770e-04
# Epoch 47/60
# 19/19 [==============================] - 3s 155ms/step - loss: 2.4606e-04 - val_loss: 2.1393e-04
# Epoch 48/60
# 19/19 [==============================] - 2s 128ms/step - loss: 2.3296e-04 - val_loss: 3.6323e-04
# Epoch 49/60
# 19/19 [==============================] - 3s 134ms/step - loss: 2.6211e-04 - val_loss: 1.9744e-04
# Epoch 50/60
# 19/19 [==============================] - 3s 143ms/step - loss: 2.1585e-04 - val_loss: 1.8878e-04
# Epoch 51/60
# 19/19 [==============================] - 3s 155ms/step - loss: 2.3237e-04 - val_loss: 1.8268e-04
# Epoch 52/60
# 19/19 [==============================] - 2s 127ms/step - loss: 2.0448e-04 - val_loss: 1.7835e-04
# Epoch 53/60
# 19/19 [==============================] - 3s 138ms/step - loss: 1.9843e-04 - val_loss: 2.1603e-04
# Epoch 54/60
# 19/19 [==============================] - 3s 151ms/step - loss: 2.2630e-04 - val_loss: 2.1669e-04
# Epoch 55/60
# 19/19 [==============================] - 3s 131ms/step - loss: 2.1291e-04 - val_loss: 1.7585e-04
# Epoch 56/60
# 19/19 [==============================] - 3s 171ms/step - loss: 1.9718e-04 - val_loss: 1.6443e-04
# Epoch 57/60
# 19/19 [==============================] - 3s 163ms/step - loss: 1.8552e-04 - val_loss: 1.9460e-04
# Epoch 58/60
# 19/19 [==============================] - 3s 141ms/step - loss: 1.9613e-04 - val_loss: 1.5990e-04
# Epoch 59/60
# 19/19 [==============================] - 4s 217ms/step - loss: 1.7966e-04 - val_loss: 1.6052e-04
# Epoch 60/60
# 19/19 [==============================] - 4s 197ms/step - loss: 1.7323e-04 - val_loss: 2.0602e-04

# %%
test_predict = model.predict(X_test)

# %%
# transform to original test set
test_predict1 = scaler.inverse_transform(test_predict)

# %%
test_predict1
# Out:
# array([[143.96233 ],
#        [144.07039 ],
#        [142.95555 ],
#        [139.82224 ],
#        [138.20874 ],
#        [138.20654 ],
#        [140.08252 ],
#        [141.90619 ],
#        [141.7717  ],
#        [140.67711 ],
#        [140.19804 ],
#        [141.89497 ],
#        [143.10847 ],
#        [144.9108  ],
#        [147.24893 ],
#        [144.3393  ],
#        [141.16518 ],
#        [141.27911 ],
#        [142.8693  ],
#        [149.23618 ],
#        [153.9033  ],
#        [154.89479 ],
#        [153.91695 ],
#        [151.14124 ],
#        [151.63977 ],
#        [152.40938 ],
#        [153.31917 ],
#        [155.15677 ],
#        [155.4666  ],
#        [154.82697 ],
#        [155.01596 ],
#        [153.67421 ],
#        [149.94023 ],
#        [143.54257 ],
#        [140.38017 ],
#        [140.39844 ],
#        [141.20088 ],
#        [139.94133 ],
#        [136.51065 ],
#        [131.87544 ],
#        [129.4164  ],
#        [129.02214 ],
#        [127.313065],
#        [126.67682 ],
#        [124.40358 ],
#        [121.36647 ],
#        [120.8871  ],
#        [121.09277 ],
#        [121.73584 ],
#        [120.63081 ],
#        [119.427765],
#        [118.96456 ],
#        [118.192986],
#        [118.55901 ],
#        [120.345055],
#        [122.48811 ],
#        [124.48799 ],
#        [124.88106 ],
#        [124.05825 ],
#        [123.83878 ],
#        [124.16389 ],
#        [124.20683 ],
#        [124.57022 ],
#        [125.07604 ],
#        [125.24831 ],
#        [125.15968 ],
#        [124.802315],
#        [125.10286 ],
#        [125.66372 ],
#        [126.060165],
#        [125.04098 ],
#        [123.756836],
#        [122.23061 ],
#        [120.990105],
#        [119.75847 ],
#        [120.20478 ],
#        [121.124695],
#        [122.24265 ],
#        [123.2898  ],
#        [124.40764 ],
#        [125.45912 ],
#        [126.03679 ],
#        [126.383095],
#        [126.326164],
#        [126.13484 ],
#        [125.90716 ],
#        [126.94566 ],
#        [127.45091 ],
#        [128.48409 ],
#        [129.25903 ],
#        [129.49663 ],
#        [129.78682 ],
#        [130.79936 ],
#        [130.23166 ],
#        [129.47795 ],
#        [129.3876  ],
#        [129.7112  ],
#        [130.37811 ],
#        [131.40413 ],
#        [131.54361 ],
#        [131.56476 ],
#        [134.64198 ],
#        [139.93477 ],
#        [144.16478 ],
#        [145.12349 ],
#        [145.95305 ],
#        [145.86072 ],
#        [145.38258 ],
#        [144.21758 ],
#        [143.02496 ],
#        [141.46188 ],
#        [141.09276 ],
#        [141.6406  ],
#        [142.92003 ],
#        [143.87373 ],
#        [143.39023 ],
#        [142.06859 ],
#        [140.93752 ],
#        [140.14066 ],
#        [142.26515 ],
#        [143.80049 ],
#        [144.89046 ],
#        [145.27133 ],
#        [144.93831 ],
#        [143.88289 ],
#        [142.78516 ],
#        [140.65714 ],
#        [140.06679 ],
#        [141.32407 ],
#        [144.4634  ],
#        [146.9447  ],
#        [148.38791 ],
#        [148.43263 ],
#        [146.58543 ],
#        [148.71309 ],
#        [151.95503 ],
#        [152.46974 ],
#        [152.11702 ],
#        [151.93607 ],
#        [151.86873 ],
#        [152.08754 ],
#        [153.0013  ],
#        [154.1568  ],
#        [154.97047 ],
#        [153.99208 ],
#        [152.84464 ],
#        [153.6224  ],
#        [154.17926 ],
#        [153.47755 ],
#        [152.03645 ],
#        [150.50723 ],
#        [150.78384 ],
#        [152.75719 ],
#        [153.92291 ],
#        [154.17082 ],
#        [153.81271 ],
#        [154.44458 ],
#        [154.51222 ],
#        [154.62263 ],
#        [157.03992 ],
#        [158.62569 ],
#        [158.2585  ],
#        [155.74481 ],
#        [153.93654 ],
#        [154.42027 ],
#        [156.09138 ],
#        [156.76974 ],
#        [155.79228 ],
#        [155.61465 ],
#        [156.05013 ],
#        [155.64491 ],
#        [152.32086 ],
#        [150.39415 ],
#        [149.67558 ],
#        [148.26341 ],
#        [145.62024 ],
#        [144.39842 ],
#        [146.40392 ],
#        [148.14424 ],
#        [148.4998  ],
#        [149.77385 ],
#        [152.4602  ],
#        [155.55885 ],
#        [157.154   ],
#        [156.17473 ],
#        [155.88239 ],
#        [156.0016  ],
#        [156.12514 ],
#        [155.06107 ],
#        [156.16544 ],
#        [158.9629  ],
#        [161.20416 ],
#        [161.31667 ],
#        [159.49771 ],
#        [158.22273 ],
#        [158.10506 ],
#        [157.498   ],
#        [155.02841 ],
#        [151.16812 ],
#        [149.77509 ],
#        [150.12314 ],
#        [151.84097 ],
#        [153.56068 ],
#        [153.43129 ],
#        [155.38057 ],
#        [156.19685 ],
#        [157.89081 ],
#        [163.69135 ],
#        [169.91093 ],
#        [174.67404 ],
#        [176.9494  ],
#        [176.34737 ],
#        [176.7116  ],
#        [175.98758 ],
#        [175.97893 ],
#        [174.38992 ],
#        [173.54433 ],
#        [172.53697 ],
#        [172.60513 ],
#        [173.67638 ],
#        [172.22504 ],
#        [170.73524 ],
#        [170.56717 ],
#        [169.87952 ],
#        [167.8194  ],
#        [167.23193 ],
#        [167.67227 ],
#        [170.31047 ],
#        [169.82175 ],
#        [165.79987 ],
#        [159.65443 ],
#        [160.8628  ],
#        [172.84438 ],
#        [190.62115 ],
#        [197.39462 ],
#        [196.26904 ],
#        [194.91875 ],
#        [191.6558  ],
#        [194.04602 ],
#        [196.27588 ],
#        [195.86504 ],
#        [192.94487 ],
#        [195.53441 ],
#        [199.48471 ],
#        [200.29347 ],
#        [196.26866 ],
#        [195.55984 ],
#        [203.06956 ],
#        [208.08609 ],
#        [208.2802  ],
#        [208.29639 ],
#        [210.75728 ],
#        [209.36261 ],
#        [210.53418 ],
#        [211.39757 ],
#        [213.15257 ],
#        [215.9983  ],
#        [215.35628 ],
#        [212.77487 ],
#        [204.3454  ],
#        [197.31305 ],
#        [201.88844 ],
#        [203.06917 ],
#        [203.50578 ],
#        [205.23009 ],
#        [206.53247 ],
#        [205.48618 ],
#        [207.36961 ],
#        [209.44434 ],
#        [208.97818 ],
#        [208.12231 ],
#        [208.848   ],
#        [211.56651 ],
#        [211.74965 ],
#        [210.24051 ],
#        [210.05698 ],
#        [208.37073 ],
#        [205.74747 ],
#        [203.85406 ],
#        [208.05399 ],
#        [208.3319  ],
#        [209.12122 ],
#        [217.119   ],
#        [226.11163 ],
#        [228.01122 ],
#        [226.48544 ],
#        [225.10059 ],
#        [224.94093 ],
#        [232.33409 ],
#        [229.7246  ],
#        [224.52782 ],
#        [235.26453 ],
#        [240.19807 ],
#        [235.89659 ],
#        [241.63881 ],
#        [250.4147  ],
#        [252.75528 ],
#        [256.81604 ],
#        [270.45166 ],
#        [274.5962  ],
#        [272.34354 ],
#        [272.81537 ],
#        [278.53772 ],
#        [280.10345 ],
#        [286.91962 ],
#        [283.96375 ],
#        [286.13666 ],
#        [286.5937  ],
#        [282.19818 ],
#        [281.6403  ],
#        [279.31857 ],
#        [285.26376 ],
#        [291.44052 ],
#        [298.52408 ],
#        [290.74435 ],
#        [283.82336 ],
#        [286.3076  ],
#        [291.4046  ],
#        [294.27084 ],
#        [301.10205 ],
#        [303.09714 ],
#        [301.23047 ],
#        [303.6072  ],
#        [308.79837 ],
#        [309.5023  ],
#        [309.29233 ],
#        [318.2314  ],
#        [318.7448  ],
#        [314.34344 ],
#        [314.7861  ],
#        [318.21945 ],
#        [319.21808 ],
#        [322.04782 ],
#        [321.0786  ],
#        [319.07898 ],
#        [318.93887 ],
#        [330.10342 ],
#        [330.70746 ],
#        [320.998   ],
#        [317.9359  ],
#        [314.81662 ],
#        [316.2222  ],
#        [317.0783  ],
#        [314.1207  ],
#        [310.07452 ],
#        [309.93103 ],
#        [308.72122 ],
#        [309.28424 ],
#        [298.25992 ],
#        [292.4985  ],
#        [283.646   ],
#        [279.61798 ],
#        [274.60004 ],
#        [282.8593  ],
#        [285.90134 ],
#        [280.0264  ],
#        [282.91544 ],
#        [284.33096 ],
#        [280.8378  ],
#        [276.8866  ],
#        [271.24277 ],
#        [266.42465 ],
#        [269.23828 ],
#        [267.3766  ],
#        [270.93546 ],
#        [274.9861  ],
#        [275.68094 ],
#        [275.08    ],
#        [274.8858  ],
#        [276.2493  ],
#        [275.94452 ],
#        [271.30072 ],
#        [273.6684  ],
#        [272.44257 ],
#        [276.41605 ],
#        [280.1933  ],
#        [279.93994 ],
#        [279.74176 ],
#        [274.78766 ],
#        [263.89557 ],
#        [263.3117  ],
#        [267.61972 ],
#        [264.00632 ],
#        [259.12708 ],
#        [262.07974 ],
#        [265.69232 ],
#        [260.95093 ],
#        [271.916   ],
#        [277.1165  ],
#        [270.6123  ],
#        [269.9642  ],
#        [273.5978  ],
#        [279.00467 ],
#        [277.84744 ],
#        [274.49707 ],
#        [274.75378 ],
#        [277.6691  ],
#        [281.54868 ],
#        [282.75577 ],
#        [284.5143  ],
#        [287.06543 ],
#        [287.85162 ],
#        [285.5239  ],
#        [284.77475 ],
#        [290.6954  ],
#        [294.5572  ],
#        [294.12436 ],
#        [297.80038 ],
#        [296.2446  ],
#        [289.6647  ],
#        [290.02762 ],
#        [297.97675 ],
#        [295.71545 ],
#        [293.37006 ],
#        [289.04276 ],
#        [290.306   ],
#        [266.05527 ],
#        [246.00143 ],
#        [247.04358 ],
#        [255.96251 ],
#        [252.08948 ],
#        [243.73347 ],
#        [244.47682 ],
#        [249.5921  ],
#        [253.40578 ],
#        [255.3493  ],
#        [257.5492  ],
#        [256.28232 ],
#        [261.16846 ],
#        [268.38666 ],
#        [265.17688 ],
#        [255.64723 ],
#        [261.29074 ],
#        [269.11536 ],
#        [269.77203 ],
#        [267.0969  ],
#        [264.29123 ],
#        [267.70944 ],
#        [271.59665 ],
#        [277.73938 ],
#        [274.49152 ],
#        [273.92133 ],
#        [269.66266 ],
#        [263.31607 ],
#        [260.6008  ],
#        [264.4959  ],
#        [267.68347 ],
#        [268.5368  ],
#        [266.2025  ],
#        [263.9588  ],
#        [268.5376  ],
#        [267.25284 ],
#        [277.58118 ],
#        [279.9476  ],
#        [271.83624 ],
#        [265.6928  ],
#        [274.79883 ],
#        [279.58185 ],
#        [272.67294 ],
#        [265.458   ],
#        [261.41556 ],
#        [249.57541 ],
#        [248.92389 ],
#        [245.0579  ],
#        [236.9144  ],
#        [238.00044 ],
#        [244.0707  ],
#        [246.83856 ],
#        [237.88303 ],
#        [234.82062 ],
#        [240.16902 ],
#        [243.12706 ],
#        [245.36574 ],
#        [237.41269 ],
#        [233.16107 ],
#        [234.56529 ],
#        [239.8559  ],
#        [239.75311 ],
#        [236.3785  ],
#        [236.05667 ],
#        [234.64583 ],
#        [234.43213 ],
#        [237.0713  ],
#        [239.56914 ],
#        [242.23866 ],
#        [244.36763 ],
#        [241.22583 ],
#        [235.49985 ],
#        [231.32513 ],
#        [236.03503 ],
#        [236.70326 ],
#        [235.02838 ],
#        [235.26427 ],
#        [234.82372 ],
#        [235.97917 ],
#        [227.1532  ],
#        [221.16913 ],
#        [221.1379  ],
#        [223.95717 ],
#        [223.74312 ],
#        [217.66359 ],
#        [219.27452 ],
#        [230.81877 ],
#        [237.61324 ],
#        [234.99226 ],
#        [231.96242 ],
#        [232.67554 ],
#        [233.67279 ],
#        [235.88338 ],
#        [235.48193 ]], dtype=float32)

# %% [markdown]
# ## Error Evaluation

# %%
import math
from sklearn.metrics import mean_squared_error
import sklearn.metrics as metrics
math.sqrt(mean_squared_error(ytest, test_predict))
# Out:
# 0.022210034029766023
