# %% [markdown]
# ## MATPLOTLIB INTRODUCTION

# %% [markdown]
# Matplotlib is considered the "grandfather" libraray of data visualisation with Python. Matplotlib is a low level graph plotting library in python that serves as a visualization utility. It was created by John D. Hunter.

# %% [markdown]
# ## Installation and Importing

# %% [markdown]
# At first we need to install it using either
#
# `conda install matplotlib`
#
# or
#
#  `pip install matplotlib`

# %% [markdown]
# Next to import it inside our working space, use:
#
# `import matplotlib.pyplot as plt`
#
# Most of the Matplotlib utilities lies under the pyplot submodule. We use plt as a shorthand-name for the library.
#
# We can also use the following command to see plots in the notebook itself:
#
# `%matplotlib inline`

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ### Basic Example

# %% [markdown]
# Let's see a basic example of using Matlplotlib for visualisation by passing two numpy arrays.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

x = np.array([4,6])
y = np.array([300,500])

plt.plot(x,y)

# %% [markdown]
# This was a basic example to demonstrate working of Matplotlib library. Here, we understand the notion of x-axis, and y-axis, as we plotted a straight line through the points.
#
# ---
#
#
#
# ---

# %% [markdown]
# # Common Commands used in Matplotlib:
#
# We can specify the labels for x-axis and y-axis, the title of our plot as follows:

# %%
x = np.array([4,6,8])
y = np.array([300,500,800])

plt.plot(x,y, 'o')
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('Plot Title Here')
# Out:
# Text(0.5, 1.0, 'Plot Title Here')

# %% [markdown]
# ### Changing the Font Properties of Labels
#
# We can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels after specifying a dictionary for what all font properties we want to have.

# %%
x = np.array([4,6,8])
y = np.array([300,500,800])

fontX = {'family':'serif', 'color':'red', 'size':'10'}
fontY = {'family':'serif', 'color':'blue', 'size':'10'}
fontTitle = {'family':'ubuntu', 'color':'green', 'size':'20'}

plt.plot(x,y, 'o')
plt.xlabel('X Axis Title Here',fontdict = fontX)
plt.ylabel('Y Axis Title Here', fontdict = fontY)
plt.title('Plot Title Here', fontdict = fontTitle)
# Out:
# Text(0.5, 1.0, 'Plot Title Here')
# findfont: Font family ['ubuntu'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## Positioning the Title
#
# Using the 'loc' attribute, we can specify the position of the title, i.e. 'left', 'right', or 'center'.

# %%
x = np.array([4,6,8])
y = np.array([300,500,800])

fontX = {'family':'serif', 'color':'red', 'size':'10'}
fontY = {'family':'serif', 'color':'blue', 'size':'10'}
fontTitle = {'family':'serif', 'color':'green', 'size':'20'}

plt.plot(x,y, 'o')
plt.xlabel('X Axis Title Here',fontdict = fontX)
plt.ylabel('Y Axis Title Here', fontdict = fontY)
plt.title('Plot Title Here', fontdict = fontTitle, loc = 'left')
# Out:
# Text(0.0, 1.0, 'Plot Title Here')

# %% [markdown]
# # Markers

# %% [markdown]
# ## Marker Styles
#
# Instead of always having a line through all the points, we can have the points marked by various kinds of markers:

# %%
x = np.array([4,6,8])
y = np.array([300,500,800])

plt.plot(x,y, 'o')

# %% [markdown]
#
# Here, we used 'o' to indicate what shape of marker we want.
#
# Also, we can specify it as `plt.plot(x,y, marker = 'o')`
#
# Other marker styles include: '*', 'x', 's'(square), 'D'(diamond)

# %% [markdown]
# ## Marker Size
#
# We can use the keyword argument markersize or the shorter version, ms to set the size of the markers:

# %%
x = np.array([4,6,8])
y = np.array([300,500,800])

plt.plot(x,y, marker = 'o', ms = 20)

# %% [markdown]
# ## Marker Edge Color and Marker Face Color
#
# We can use the keyword argument markeredgecolor or the shorter mec to set the color of the edge of the markers, and similarly we can use markerfacecolor or the shorter mfc to set the color inside the edge of the markers:

# %%
x = np.array([4,6,8])
y = np.array([300,500,800])

plt.plot(x,y, marker = 'o', ms = 20, mec = 'r', mfc = 'g')

# %% [markdown]
# ## Linestyle
#
# We use the keyword argument linestyle, or shorter ls, to change the style of the plotted line. Some coomon linestyles include '-'(solid), ':'(dotted), '--'(dashed).

# %%
x = np.array([4,6,8])
y = np.array([300,500,800])

plt.plot(x,y, ls = ':')

# %% [markdown]
# ## Line Color
#
# We use the keyword argument color or the shorter c to set the color of the line:

# %%
x = np.array([4,6,8])
y = np.array([300,500,800])

plt.plot(x,y, c = 'r')

# %% [markdown]
# We can also add some transparency to the color using 'alpha' proprty:

# %%
x = np.array([4,6,8])
y = np.array([300,500,800])

plt.plot(x,y, c = 'r', alpha = 0.5)

# %% [markdown]
# ## Line Width
#
# Use the keyword argument linewidth or the shorter lw to change the width of the line.
#
# The value is a floating number, in points:

# %%
x = np.array([4,6,8])
y = np.array([300,500,800])

plt.plot(x,y, lw = '10.6')

# %% [markdown]
# # Multiple Lines on the Same Plot
#
# If we want to have many plot lines on the same graph, we can simply add more of plt.plot() statements accordingly.

# %%
x = np.array([4,6,8])
y1 = np.array([300,500,800])
y2 = np.array([60,366,349])

plt.plot(x,y1, c='orange')
plt.plot(x,y2, c='g')

# %% [markdown]
# # Grid
#
# We can have a grid instead of the plain canvas in the background, and also add some proprties and styling to the grid just the way we did for the plots:

# %%
x = np.array([4,6,8])
y = np.array([300,500,800])

plt.plot(x,y, lw = '10.6')

plt.grid(color = 'green', linestyle = ':', linewidth = 0.5)

# %% [markdown]
# # Subplots
#
# At times, we wish to draw multiple plots on the same canvas using subplots.

# %% [markdown]
# ## Example

# %%
x1 = np.array([4,6,8])
x2 = np.array([20,30,50])
y1 = np.array([300,500,800])
y2 = np.array([60,366,349])

plt.subplot(1, 2, 1)
plt.plot(x1, y1, 'r') 

plt.subplot(1,2,2)
plt.plot(x2, y2, 'g')

# %% [markdown]
# ## Adding Titles
#
# Adding Titles to each subplot and also to the whole canvas using **plt.title()** and plt.suptitle():

# %%
x1 = np.array([4,6,8])
x2 = np.array([20,30,50])
y1 = np.array([300,500,800])
y2 = np.array([60,366,349])

plt.subplot(1, 2, 1)
plt.plot(x1, y1, 'r')
plt.title('plot1')

plt.subplot(1,2,2)
plt.plot(x2, y2, 'g')
plt.title('plot2')

plt.suptitle('Canvas')
# Out:
# Text(0.5, 0.98, 'Canvas')

# %% [markdown]
# ## Example with Alternative way
#
# Creating subplots in another way using axes.

# %%
x1 = np.array([4,6,8])
x2 = np.array([20,30,50])
y1 = np.array([300,500,800])
y2 = np.array([400,900,2500])

fig = plt.figure(figsize=(10,10))

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# Larger Figure Axes 1
axes1.plot(x1, y1, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# Insert Figure Axes 2
axes2.plot(x2, y2, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %% [markdown]
# # Adding legend
#
# You can use the **label="label text"** keyword argument when plots or other objects are added to the figure, and then using the **legend** method without arguments to add the legend to the figure:

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="x**3")
ax.legend()

# %% [markdown]
# # Visualisation of various plots

# %% [markdown]
# ## Scatter Plot
#
# With Pyplot, you can use the **scatter()** function to draw a scatter plot.
#
# The scatter() function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %%
x = np.array([4,645,32,435,324,32,433,332])
y = np.array([434,454,322,543,544,433,343,443])

plt.scatter(x, y, color = 'red')

# %% [markdown]
# ## Bar Plot
#
# With Pyplot, you can use the **bar()** function to draw bar graphs. The bar() function takes arguments that describes the layout of the bars.
#
# The categories and their values represented by the first and second argument as arrays.

# %%
x = ["A", "B", "C", "D"]
y = [3,5,2,6]

plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# We can play around with the attributes of color, and width of the bar as:

# %%
x = ["A", "B", "C", "D"]
y = [3,5,2,6]

plt.bar(x,y, color = 'green', width = 1.5)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# We might also want to have horizontal bars in place of vertical, in that case, we can do use **barh()**

# %%
x = ["A", "B", "C", "D"]
y = [3,5,2,6]

plt.barh(x,y)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Histogram
#
# In Matplotlib, we use the **hist()** function to create histograms.
#
# The hist() function will use an array of numbers to create a histogram, the array is sent into the function as an argument. A histogram is a graph showing frequency distributions. It is a graph showing the number of observations within each given interval.

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([12.,  7., 13., 14.,  6., 11., 14.,  5.,  7., 11.]),
#  array([ 17. , 114.4, 211.8, 309.2, 406.6, 504. , 601.4, 698.8, 796.2,
#         893.6, 991. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Box Plot
#
# We use **plt.boxplot()** to draw out a box plot for the data.
#
# In descriptive statistics, a box plot or boxplot is a method for graphically depicting groups of numerical data through their quartiles. Box plots may also have lines extending from the boxes indicating variability outside the upper and lower quartiles, hence the terms box-and-whisker plot and box-and-whisker diagram.

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

plt.boxplot(data, vert=True, patch_artist=True)
# Out:
# {'boxes': [<matplotlib.patches.PathPatch at 0x7f45a8c23090>,
#   <matplotlib.patches.PathPatch at 0x7f45a8c313d0>,
#   <matplotlib.patches.PathPatch at 0x7f45a8c41510>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f45a8c2a610>,
#   <matplotlib.lines.Line2D at 0x7f45a8c2ab50>,
#   <matplotlib.lines.Line2D at 0x7f45a8c37890>,
#   <matplotlib.lines.Line2D at 0x7f45a8c37d50>,
#   <matplotlib.lines.Line2D at 0x7f45a8c4c9d0>,
#   <matplotlib.lines.Line2D at 0x7f45a8c4cf10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f45a8c31650>,
#   <matplotlib.lines.Line2D at 0x7f45a8c41790>,
#   <matplotlib.lines.Line2D at 0x7f45a8bd2950>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f45a8c310d0>,
#   <matplotlib.lines.Line2D at 0x7f45a8c41290>,
#   <matplotlib.lines.Line2D at 0x7f45a8bd2450>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f45a8c23b10>,
#   <matplotlib.lines.Line2D at 0x7f45a8c2a0d0>,
#   <matplotlib.lines.Line2D at 0x7f45a8c31e10>,
#   <matplotlib.lines.Line2D at 0x7f45a8c37390>,
#   <matplotlib.lines.Line2D at 0x7f45a8c41f10>,
#   <matplotlib.lines.Line2D at 0x7f45a8c4c4d0>]}

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## Pie Charts
#
# With Pyplot, you can use the **pie()** function to draw pie charts.
#
# The pie chart draws one piece (called a wedge) for each value in the array. By default the plotting of the first wedge starts from the x-axis and move counterclockwise.
#
# We also write down the labels for each segment using **labels** keyword.

# %%
plt.figure(figsize=(20,8))

y = np.array([40,25,5,30])
mylabels = ["Singing", "Dancing", "Gardening", "Reading"]

plt.pie(y, labels = mylabels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f45a8d32050>,
#   <matplotlib.patches.Wedge at 0x7f45a8d32450>,
#   <matplotlib.patches.Wedge at 0x7f45a8d32410>,
#   <matplotlib.patches.Wedge at 0x7f45a8d32ad0>],
#  [Text(0.33991867422268784, 1.0461621742897658, 'Singing'),
#   Text(-1.086457168210212, -0.17207795223283867, 'Dancing'),
#   Text(-0.49938951071369203, -0.9801071964785992, 'Gardening'),
#   Text(0.6465638483438898, -0.88991864235712, 'Reading')])

# %% [markdown]
# We can change the value of the Start Angle for pie chart using **startangle** keyword.
#
# Also, if we want to explode a particular segment out, we can do that with the use of **explode** keyword. The values in this array represent how far from the centre, each segment of the pie chart would be.

# %%
plt.figure(figsize=(20,8))

y = np.array([40,25,5,30])
mylabels = ["Singing", "Dancing", "Gardening", "Reading"]
array = [0,0,0,0.2]

plt.pie(y, labels = mylabels, startangle = 90, explode = array)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f45a8d52f90>,
#   <matplotlib.patches.Wedge at 0x7f45a8d603d0>,
#   <matplotlib.patches.Wedge at 0x7f45a8d60390>,
#   <matplotlib.patches.Wedge at 0x7f45a8d60a50>],
#  [Text(-1.0461621742897658, 0.3399186742226879, 'Singing'),
#   Text(0.17207795223283862, -1.086457168210212, 'Dancing'),
#   Text(0.9801071964785992, -0.4993895107136921, 'Gardening'),
#   Text(1.0517220318765963, 0.7641209116791423, 'Reading')])

# %% [markdown]
# We can further customize it by adding shadow effects or personalizing the colors according to ourselves, using **shadow** and **colors** keywords.

# %%
plt.figure(figsize=(20,8))

y = np.array([40,25,5,30])
mylabels = ["Singing", "Dancing", "Gardening", "Reading"]
array = [0,0,0,0.2]
mycolors = ['black','green','yellow','red']

plt.pie(y, labels = mylabels, startangle = 90, explode = array, shadow = True, colors = mycolors)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f45a8e00210>,
#   <matplotlib.patches.Wedge at 0x7f45a8e00590>,
#   <matplotlib.patches.Wedge at 0x7f45a8e00f50>,
#   <matplotlib.patches.Wedge at 0x7f45a8e0a850>],
#  [Text(-1.0461621742897658, 0.3399186742226879, 'Singing'),
#   Text(0.17207795223283862, -1.086457168210212, 'Dancing'),
#   Text(0.9801071964785992, -0.4993895107136921, 'Gardening'),
#   Text(1.0517220318765963, 0.7641209116791423, 'Reading')])

# %% [markdown]
# We can further go on to add a legend for the labels in our pie chart, along with a label header, using **legend** and **title** keywords.

# %%
plt.figure(figsize=(20,8))

y = np.array([40,25,5,30])
mylabels = ["Singing", "Dancing", "Gardening", "Reading"]

plt.pie(y, labels = mylabels)

plt.legend( title = "Hobbies:")

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # Conclusion
#
# We learn that Matplotlib is an extrememly rich and extensive library for data visualisations. It is easy to use and user-friendly, without any hassles of remembering tiny nuances that might cause bugs if tweaked a little.
#
# Everything ranging from a simple line plot to elaborate Pie charts can be easily visualised and customised according to the needs of the user.
#
#
# ---
