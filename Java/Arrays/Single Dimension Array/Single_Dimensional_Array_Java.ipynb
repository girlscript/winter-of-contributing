# %% [markdown]
# <a href="https://colab.research.google.com/github/firefistacez/winter-of-contributing/blob/Java/Java/Arrays/Single%20Dimension%20Array/Single_Dimensional_Array_Java.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Single Dimensional Array
#
# The link below will show you a video explaining about single dimensional array in Java
#
# ![Single Dimensional Array with Java.png](data:image/png;base64,...)
# [Java Single Deminsional Array](https://drive.google.com/file/d/1rzh_vmwERyQbqeD382G9UgxdCCJjuLvX/view?usp=sharing)
#
# ### Content of the Video
# 1. Single Dimensional Array Basics
# 2. Declaration of a Single Dimensional Array
# 3. How Single Dimensional Array supports primitive data types
# 4. How Single Dimensional Array works with classes
# 5. Java Code to explain the concept.
