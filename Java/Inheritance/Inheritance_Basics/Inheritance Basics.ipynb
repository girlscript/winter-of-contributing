# %% [markdown]
# # Inheritance Basics

# %% [markdown]
# Hello Everyone!👋
#
# In this notebook we will be covering the basics of Inheritance.Before we dive deep into the concepts of Inheritance,let me give you all a basic overview of Java as a language and the basic concepts in it.

# %% [markdown]
# ### What is Java and why do we need it?

# %% [markdown]
# Java is a programming language and a computing platform first released by Sun Microsystems in 1995. Java is fast, secure, and reliable. From laptops to datacenters, game consoles to scientific supercomputers, cell phones to the Internet, Java is everywhere!

# %% [markdown]
# ### What is a Class ?

# %% [markdown]
# A class is a collections of objects having similar behavior and attributes.In order to create an object, you have to first define the class of that object

# %% [markdown]
# ### What is an Object?

# %% [markdown]
# An entity that has a state and some behavior is known as an object e.g., chair, bike, marker, pen, table, car, etc. It can be physical or logical (tangible and intangible).

# %% [markdown]
# Every real-world object has two characteristics :
# (1) Data-Part/State- This is also knows as attributes or properties.
# (2) Behaviour- This is also knows as Operation/Logic Part

# %% [markdown]
# ![objects.jpg](attachment:objects.jpg)

# %% [markdown]
# ### Examples of Real World Objects:

# %% [markdown]
# #### Pencil Object:
# * ##### State/Data Part:
#     * color
#     * size.
#
#
# * ##### Behaviour Part:
#     * writting
#     * sketching
#     * drawing.

# %% [markdown]
# #### Bag Object:
# * ##### State/Data Part:
#     * color of bag
#     * height of bag
#     * width of bag
#
#
# * ##### Behaviour Part:
#     * storing items

# %% [markdown]
# Now that we have some clarity with the fundamentals of Java.Lets start with Inheritance.

# %% [markdown]
# ## Inheritance

# %% [markdown]
# Inheritance in Java is a mechanism in which one object acquires all the properties and behaviors of a parent object. It is an important part of OOPs (Object Oriented programming system).
#
# The idea behind inheritance in Java is that you can create new classes that are built upon existing classes. When you inherit from an existing class, you can reuse methods and fields of the parent class. Moreover, you can add new methods and fields in your current class also.
#
# Suppose A is super class of B. Then class B can inherit all the features (Methods and Instance Fields) of class A except the private members.
# Super and Sub Classes May Either Belong to Same  or Different Packages

# %% [markdown]
# * The class whose properties are extended is known as super or base or parent class.
#
# * The class which  extends the properties of super class is known as sub or derived or child class.
#
# * A class can either extends another class or can implement an interface

# %% [markdown]
# Inheritance represents the **IS-A relationship** which is also known as a parent-child relationship.
# ![](https://media.geeksforgeeks.org/wp-content/cdn-uploads/Access-Modifiers-in-Java.png)

# %% [markdown]
# ## Java’s Support For Inheritance

# %% [markdown]
# ![Cae.PNG](attachment:Cae.PNG)

# %% [markdown]
# ### Extending a Class
#
# class 	class-name	extends		super-class-name
# {
#
# }
#
# ##### Example:
# class  A
# {
#
# }// End of class A
#
# class 	B  extends  A
# {
#
# }// End of class B

# %% [markdown]
# ### Implementing an Interface
#
# class class-name implements	interface-name
# {
#
# }
# ##### Example
# interface A
# {
#
# }// End of interface A
#
# class 	B  implements  A
# {
#
# }// End of class B

# %% [markdown]
# ## Types of Inheritance

# %% [markdown]
# ![C.PNG](attachment:C.PNG)

# %% [markdown]
# ### Single-level Inheritance:

# %% [markdown]
# When a class inherits another class, it is known as a single inheritance.There is a single child class and a single parent class, as depicted in the image above.Let us understand this with the help of an example.

# %% [markdown]
# ![s1.PNG](attachment:s1.PNG)

# %% [markdown]
# ![o2.PNG](attachment:o2.PNG)

# %% [markdown]
# In the above example we have two classes:
# * ProgrammingLanguages is the parent class.
#     * This class has a method called message().
# * Java Class is the child class.
#     * This class has a method called print().
# * The child class object can access the methods and variables of the Parent class.This is called Single-level Inheritance

# %% [markdown]
# ### Multi-level Inheritance:

# %% [markdown]
# When there is a chain of inheritance, it is known as multilevel inheritance. As you can see in the example given below, the Child class inherits the Parent class, which inherits the GrandParent Class.So there is a chain of inheritance.This is called as Multilevel Inheritance.

# %% [markdown]
# ![s2-2.PNG](attachment:s2-2.PNG)

# %% [markdown]
# ![o1.PNG](attachment:o1.PNG)

# %% [markdown]
# In the above example we have three classes:
# * Grandparent Class is the base class.
#     * This class has a method called mssg1().
# * Parent Class inherits the Grandparent class and is the parent of Child class.
#     * This class has a method called mssg2().
# * Child Class inherits both the Parent and the Grandaparent Classes.
#     * This class has a method called mssg3().
# * The child class object can access the methods and variables of the Parent class and the Grandparent class.This is called Multilevel-level Inheritance

# %% [markdown]
# ### Hierarchical Inheritance:

# %% [markdown]
# When two or more classes inherits a single class, it is known as hierarchical inheritance. In the example given below, both Java and Python Class extend the ProgrammingLanguages Class.

# %% [markdown]
# ![s3-3.PNG](attachment:s3-3.PNG)

# %% [markdown]
# ![o3.PNG](attachment:o3.PNG)

# %% [markdown]
# In the above example we have three classes:
# * ProgrammingLanguages is the parent class.
#     * This class has a method called message().
# * Java Class is the child class as it inherits the ProgrammingLanguages class.
#     * This class has a method called print1().
# * Python Class is the child class as it inherits the ProgrammingLanguages class.
#     * This class has a method called print2().
# * The child class object can access the methods and variables of the parent class.This is called Hierarchical Inheritance

# %% [markdown]
# ### Multiple Inheritance:

# %% [markdown]
# #### 1) Java Does Not Support Multiple Inheritance by Extending Multiple Classes.
#
# The Following Code is Wrong
#
# class 	A
# {
#
# } // End of class A
# class   B
# {
#
# } // End of class B
# class C extends A,B
# {
#
# }// End of class C
#
# #### 2) Java Supports Multiple Inheritance by Implementing Multiple Interfaces
#
# The Following Code is Correct
#
# interface   A
# {
#
# } // End of interface A
# interface   B
# {
#
# } // End of interface B
#
# class	C	implements 	A, B
# {
#
# }// End of class C

# %% [markdown]
# # Conclusion

# %% [markdown]
# In this notebook we discussed the basic concepts of Inheritance.Hopefully it was helpful to you all! Happy Coding!:)

# %% [markdown]
# # References

# %% [markdown]
# 1) https://www.javatpoint.com/inheritance-in-java
# 2) https://www.java.com/en/download/help/whatis_java.html
