# %% [markdown]
# # **1.1 THEORETICAL SECTION**

# %% [markdown]
# # AIM

# %% [markdown]
# we will study about the details of hosting our code onto the remote online repository.

# %% [markdown]
# # GITHUB TERMINOLIGIES
#
# ***
#
# ## REPOSITORY:-
#
# Repository is a place, room, or container where something is deposited or stored. stored content may be your any type of file.
#
# ## FORKING:-
#
# a Github Fork is a copy of the Repository (repo) that sits in your account rather than the account from which you forked the data from. Once you have forked a repo, you own your forked copy. This means that you can edit the contents of your forked repository without impacting the parent repo.

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/git-fork-emphasis.png')

# %% [markdown]
# ## CLONING and FORKING:-
#
# Cloning a GitHub repository creates a local copy of the remote repo. This allows you to make all of your edits locally rather than directly in the source files of the origin repo.
#
# Image below will give you clear understanding of the whole process of forking and cloning and making changes to the cloned file/folder in your local machine. There is also a thing called Pushing.
#
# Pushing is how you transfer commits from your local repository to a remote repo.

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/git-fork-clone-flow (1).png')

# %% [markdown]
# ## PULL REQUEST:-
#
# Pull requests let you tell others about changes you've pushed to a branch in a repository on GitHub. Once a pull request is opened, you can discuss and review the potential changes with collaborators and add follow-up commits before your changes are merged into the base branch.

# %% [markdown]
# ## BRANCH:-
#
# Use a branch to isolate development work without affecting other branches in the repository. Each repository has one default branch, and can have multiple other branches. You can merge a branch into another branch using a pull request.
#
# Below image will give you a clear understanding of how a branching system works in Github.

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/git-branches-merge.png')

# %% [markdown]
# ## UPSTREAM:-
#
# When a repo is cloned, it has a default remote called origin that points to your fork on GitHub, not the original repo it was forked from.
# To keep track of the original repo, you need to add another remote named upstream

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/cEJjT.png')

# %% [markdown]
# you cannnot push to the upstream unless and until you're authorized to do so!
# you mostly fetch and merge from your upstream. Any other business such as pushing from your local to upstream should be done using pull request.

# %% [markdown]
# # **1.2 PRACTICAL SECTION:-**

# %% [markdown]
# ### let's see all those above concepts practically

# %% [markdown]
# first of all, let's fork a repository and then we will clone it in our local machine. After making changes to the file locally, we will push it to our forked repository and then will create a pull request so that the authorized user of the main repository can review my changes and merge it into his any branch. Keep in mind, in this process, we can be suggested to make any kind of changes to the changes we have made.

# %% [markdown]
# **1. FORKING A REPOSITORY**

# %% [markdown]
# let's fork the public repository of girlscript winter of coding.
#
# click on the fork button in corner of the window.
#
# This is how the page will look like before forking.

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/Screenshot 2021-09-18 123935.png')

# %% [markdown]
# Below is how page will look like after you have forked the repository.
#
# Now, in this repository you're authorized to make any kind of changes.
#
# This repository is completely yours.

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/after fork.png')

# %% [markdown]
# **NOTE**
#
# notice the changes in the upper left hand side of the page.

# %% [markdown]
# **2. CLONING THE REPOSITORY**

# %% [markdown]
# your cloned repository will be saved to the root directory of your local machine. you can open any command line and type the command `pwd` and it'll show you the root directory where your file would be saved.I'm using git bash, but you can use any according to your preferences.

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/root directory.png')

# %% [markdown]
# arrow sign indicates my root directory.

# %% [markdown]
# now, let's type the command to clone the repository. i.e, make a copy of remote repository in our local machine. for that, go on to your forked repository and click on the green button saying code and copy the limk as shown below in the image.

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/copying link.png')

# %% [markdown]
# now do the below shown steps in the command line

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/cloning.png')

# %% [markdown]
# as i have already cloned it earlier, this is showing the the 'directory already exists'. in your case, it'll be cloned sucessfully.

# %% [markdown]
# below is the shown steps in which you can use `cd` command to go inside the folder and list out all the files present there inside the folder using `ls` command.

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/inside winter of coding.png')

# %% [markdown]
# below is how we can create a text file.

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/creating a file.png')

# %% [markdown]
# now you can go inside the file and make some changes to it. to display the content of the file we will use `cat` command.

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/making changes to file.png')

# %% [markdown]
# so the content  inside the file says, 'kunal is the writer of this documentation'.

# %% [markdown]
# **3. CREATING A BRANCH:-**

# %% [markdown]
# we can view different branche using `git branch` command.
#
# we can make a different branch using the command `git branch (name of the branch)`
#
# we can move to the branch of our desire using `git checkout (name of the branch)`

# %% [markdown]
# in below steps, we have created a branch called 'smile' and checked into it.

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/creating a branch.png')

# %% [markdown]
# now we can add our changed file to the staging area.
#
# The git add command adds a change in the working directory to the staging area. It tells Git that you want to include updates to a particular file in the next commit. However, git add doesn't really affect the repository in any significant way—changes are not actually recorded until you run git commit .

# %% [markdown]
# **NOTE -** upstream generally refers to the original repo that you have forked. origin is your fork: your own repo on GitHub, clone of the original repo of GitHub

# %% [markdown]
# **NOTE -** It doesn't matter what branch you're on when you add a file, only when you commit it.

# %% [markdown]
# **4. COMMIT:-**

# %% [markdown]
# now we will first add the file to a staging area and then finally will commit the file to the 'smile' branch.

# %% [markdown]
# we can add the file to the staging area using the command `git add .`, this will add all the files into the staging area.
#
# we can commit our files in the staging area to 'smile' branch thereafter using below shown way.

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/adding file to staging area.png')

# %% [markdown]
# after committing the file to the 'smile' branch, we can now push the changes to our forked repository. remember, we are not authorized to directly push the file to the upstream, rather we can push our file to the origin.

# %% [markdown]
# **4. PUSHING**

# %% [markdown]
# we can push our changes to our forked repository using below shown command

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/pushing.png')

# %% [markdown]
# we sucessfully pushed our changes to the 'smile' branch.

# %% [markdown]
# let's see the difference it made in our forked repository.

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/viewing.png')

# %% [markdown]
# you can see the above message we have got for creating a pull request now.
#
# now we can create a new pull request for our changes to be merged in the whichever branch we desire.
#
# let's see how we can generate the pull request.

# %% [markdown]
# **5. PULL REQUEST**

# %% [markdown]
# after creating on `compare and pull request` button, we can go and choose for ourselved the branch we want our pull request to be merged in. The authority to merge lies with the owner of original repository.

# %% [markdown]
# after all this, finally we can click the button down there which says `create pull request` and olah! we created our pull request.

# %%
from IPython.display import Image
Image(filename='OneDrive - K.R. MANGALAM UNIVERSITY/Desktop/PULL REQUEST.png')

# %% [markdown]
# now wait for the review by the reviewer.

# %% [markdown]
# **6. HOW TO START YOUR OWN PROJECT**

# %% [markdown]
# for creating your own repository. you go to you profile and on upper right corner, you will see a plus sign. click that plus sign and create a new repository.

# %%
from IPython.display import Image
Image(filename=r"C:\Users\ASUS\OneDrive - K.R. MANGALAM UNIVERSITY\Desktop\creating repository.png")

# %% [markdown]
# then go and fill your desired name for the repository and you can add the description as well.
#
# you can add a README file if you wish. This is a good practice to always include a README file and tell about your project through that file to everyone.

# %%
from IPython.display import Image
Image(filename=r"C:\Users\ASUS\OneDrive - K.R. MANGALAM UNIVERSITY\Desktop\creating a repository 2.png")

# %% [markdown]
# This brings us to the end of the tutorial.

# %% [markdown]
# <hr/>

# %% [markdown]
# **NOTE**
#
# This tutorial was for demonstration purpose. Refrain from creating unnecessary pull request and spamming.
