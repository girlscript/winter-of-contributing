# %% [markdown]
# # **Downloading Python 3.9.7 (or any other version) :**
# * Click on this link to download [Python 3.9.7 for windows](https://www.python.org/ftp/python/3.9.7/python-3.9.7-amd64.exe) (64-bit) .
# * Click on this link to download [Python 3.9.7 for windows](https://www.python.org/ftp/python/3.9.7/python-3.9.7.exe) (32-bit).
# * Click on this link to download [Python 3.9.7 for MacOS](https://www.python.org/ftp/python/3.9.7/python-3.9.7-macosx10.9.pkg) .
# * For downloading any other version of python you can go to this https://www.python.org/downloads/ and choose your version.
#
# ![py.png](data:image/png;base64,...)

# %% [markdown]
# # **Installing Python on your device :**
#
#
# 1. Run the Python Installer once downloaded.
# 2. Make sure you select the “Install launcher for all users” and “Add Python 3.9 to PATH” checkboxes.
# ![py.jpeg](data:image/jpeg;base64,...)
# 3. Wait for it to complete the installation process.
# 4. After it's completion, Python is successfully installed in your system.
# 5. Kudos! python has been installed in your system, Now go to -
# > Windows Search >>> Type IDLE >>> Open it
#
# ![idle.png](data:image/png;base64,...)
